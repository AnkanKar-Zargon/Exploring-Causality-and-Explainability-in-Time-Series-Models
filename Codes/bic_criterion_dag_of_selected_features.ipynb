# %%
import pandas as pd
import numpy as np
import networkx as nx
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer
import random

# %%
# Load the dataset
initial_df = pd.read_csv("data/Derivation_dataset.csv")  # <- update path if needed
target_col = 'Outcome_Occlusion_MI'  # This column is ignored

# Drop rows with any NaN values
initial_df = initial_df.dropna()

# Ensure column names do not have leading/trailing spaces
initial_df.columns = initial_df.columns.str.strip()

selected_columns = [
    "st80_aVF", "st80_aVL", "tamp_III", "tamp_aVF", "st80_V6",
    "st80_III", "st80_V2", "tamp_aVL", "st80_V1", "tamp_V2",
    "st80_I", "tamp_I", "TpTe", "st80_V3", "tamp_V6", "fpTinfl1Axis",
    "QRSd", "tamp_V5", "fpTinfl1Mag", "HR", "pcaTamp", "mfpQRSaxis",
    "Tamp", "TrelAmp", "QRSTangle"
]

df = initial_df[selected_columns].copy()



# Drop the target and impute missing values
X_raw = df
columns = X_raw.columns
imputer = SimpleImputer(strategy='mean')
X = imputer.fit_transform(X_raw)
n, d = X.shape

# %%
# === Helper Functions ===

def compute_bic(dag, X, n):
    """Compute BIC score of the DAG structure assuming linear Gaussian CPDs."""
    bic_score = 0
    for i in range(d):
        parents = list(dag.predecessors(i))
        y = X[:, i]
        if parents:
            X_parents = X[:, parents]
            model = LinearRegression().fit(X_parents, y)
            residuals = y - model.predict(X_parents)
            rss = np.sum(residuals ** 2)
            sigma2 = rss / n
        else:
            sigma2 = np.var(y)
        log_likelihood = -0.5 * n * (np.log(2 * np.pi * sigma2) + 1)
        k = len(parents) + 1
        bic_score += log_likelihood - 0.5 * k * np.log(n)
    return bic_score

def get_random_neighbors(dag, d, sample_size=200):
    """Generate a random sample of neighboring DAGs by modifying a single edge."""
    neighbors = []
    for i in range(d):
        for j in range(d):
            if i == j:
                continue
            if dag.has_edge(i, j):
                # Try removing
                temp = dag.copy()
                temp.remove_edge(i, j)
                if nx.is_directed_acyclic_graph(temp):
                    neighbors.append(temp)
                # Try reversing
                temp = dag.copy()
                temp.remove_edge(i, j)
                temp.add_edge(j, i)
                if nx.is_directed_acyclic_graph(temp):
                    neighbors.append(temp)
            else:
                # Try adding
                temp = dag.copy()
                temp.add_edge(i, j)
                if nx.is_directed_acyclic_graph(temp):
                    neighbors.append(temp)
    return random.sample(neighbors, min(sample_size, len(neighbors)))

# %%
# === Greedy Search ===

# Start from empty DAG
dag = nx.DiGraph()
dag.add_nodes_from(range(d))

best_score = compute_bic(dag, X, n)
iteration = 0
improved = True

print("Starting Greedy Search...")

while improved and iteration < 100:
    iteration += 1
    improved = False
    neighbors = get_random_neighbors(dag, d, sample_size=150)
    scores = [(compute_bic(neigh, X, n), neigh) for neigh in neighbors]
    scores.sort(reverse=True, key=lambda x: x[0])
    if scores and scores[0][0] > best_score + 1e-3:
        best_score, dag = scores[0]
        improved = True
        print(f"Iteration {iteration}: BIC = {best_score:.2f}, Edges = {len(dag.edges())}")
    else:
        print(f"Iteration {iteration}: No improvement.")
# Out:
# Starting Greedy Search...
# Iteration 1: BIC = -495747.92, Edges = 1
# Iteration 2: BIC = -493563.93, Edges = 2
# Iteration 3: BIC = -490495.77, Edges = 3
# Iteration 4: BIC = -488217.39, Edges = 4
# Iteration 5: BIC = -486273.47, Edges = 5
# Iteration 6: BIC = -484598.55, Edges = 6
# Iteration 7: BIC = -483300.64, Edges = 7
# Iteration 8: BIC = -481909.27, Edges = 8
# Iteration 9: BIC = -479954.09, Edges = 9
# Iteration 10: BIC = -478734.54, Edges = 10
# Iteration 11: BIC = -477484.80, Edges = 11
# Iteration 12: BIC = -476429.30, Edges = 12
# Iteration 13: BIC = -475303.94, Edges = 13
# Iteration 14: BIC = -473824.83, Edges = 14
# Iteration 15: BIC = -472588.59, Edges = 15
# Iteration 16: BIC = -471691.95, Edges = 16
# Iteration 17: BIC = -470795.86, Edges = 17
# Iteration 18: BIC = -470029.75, Edges = 18
# Iteration 19: BIC = -468915.24, Edges = 19
# Iteration 20: BIC = -467883.22, Edges = 20
# Iteration 21: BIC = -467090.97, Edges = 21
# Iteration 22: BIC = -466325.91, Edges = 22
# Iteration 23: BIC = -465574.78, Edges = 23
# Iteration 24: BIC = -464507.00, Edges = 24
# Iteration 25: BIC = -463967.89, Edges = 25
# Iteration 26: BIC = -463381.37, Edges = 26
# Iteration 27: BIC = -462803.56, Edges = 27
# Iteration 28: BIC = -462403.96, Edges = 28
# Iteration 29: BIC = -461875.91, Edges = 29
# Iteration 30: BIC = -461419.83, Edges = 30
# Iteration 31: BIC = -461050.97, Edges = 31
# Iteration 32: BIC = -460667.07, Edges = 32
# Iteration 33: BIC = -460374.07, Edges = 33
# Iteration 34: BIC = -459953.25, Edges = 34
# Iteration 35: BIC = -459741.64, Edges = 35
# Iteration 36: BIC = -459537.20, Edges = 36
# Iteration 37: BIC = -459379.98, Edges = 37
# Iteration 38: BIC = -459093.42, Edges = 38
# Iteration 39: BIC = -458884.53, Edges = 39
# Iteration 40: BIC = -458719.02, Edges = 40
# Iteration 41: BIC = -458549.48, Edges = 41
# Iteration 42: BIC = -458412.68, Edges = 42
# Iteration 43: BIC = -458280.93, Edges = 43
# Iteration 44: BIC = -458155.08, Edges = 44
# Iteration 45: BIC = -458036.12, Edges = 45
# Iteration 46: BIC = -457913.74, Edges = 46
# Iteration 47: BIC = -457768.83, Edges = 47
# Iteration 48: BIC = -457647.90, Edges = 48
# Iteration 49: BIC = -457537.78, Edges = 49
# Iteration 50: BIC = -457424.17, Edges = 50
# Iteration 51: BIC = -457302.92, Edges = 51
# Iteration 52: BIC = -457208.71, Edges = 52
# Iteration 53: BIC = -457127.31, Edges = 53
# Iteration 54: BIC = -457041.67, Edges = 54
# Iteration 55: BIC = -456962.64, Edges = 55
# Iteration 56: BIC = -456859.73, Edges = 56
# Iteration 57: BIC = -456762.58, Edges = 57
# Iteration 58: BIC = -456686.12, Edges = 58
# Iteration 59: BIC = -456567.97, Edges = 59
# Iteration 60: BIC = -456499.33, Edges = 60
# Iteration 61: BIC = -456414.75, Edges = 61
# Iteration 62: BIC = -456364.49, Edges = 62
# Iteration 63: BIC = -456297.18, Edges = 63
# Iteration 64: BIC = -456241.40, Edges = 64
# Iteration 65: BIC = -456187.23, Edges = 65
# Iteration 66: BIC = -456140.47, Edges = 66
# Iteration 67: BIC = -456092.06, Edges = 67
# Iteration 68: BIC = -456044.48, Edges = 68
# Iteration 69: BIC = -455928.84, Edges = 69
# Iteration 70: BIC = -455884.13, Edges = 70
# Iteration 71: BIC = -455837.55, Edges = 71
# Iteration 72: BIC = -455798.60, Edges = 72
# Iteration 73: BIC = -455753.41, Edges = 73
# Iteration 74: BIC = -455710.36, Edges = 74
# Iteration 75: BIC = -455650.82, Edges = 75
# Iteration 76: BIC = -455622.64, Edges = 76
# Iteration 77: BIC = -455563.95, Edges = 77
# Iteration 78: BIC = -455540.14, Edges = 78
# Iteration 79: BIC = -455504.45, Edges = 79
# Iteration 80: BIC = -455480.88, Edges = 80
# Iteration 81: BIC = -455457.31, Edges = 81
# Iteration 82: BIC = -455427.54, Edges = 82
# Iteration 83: BIC = -455395.74, Edges = 83
# Iteration 84: BIC = -455375.49, Edges = 84
# Iteration 85: BIC = -455348.08, Edges = 85
# Iteration 86: BIC = -455325.78, Edges = 86
# Iteration 87: BIC = -455304.29, Edges = 87
# Iteration 88: BIC = -455278.92, Edges = 87
# Iteration 89: BIC = -455259.57, Edges = 88
# Iteration 90: BIC = -455238.26, Edges = 89
# Iteration 91: BIC = -455213.58, Edges = 90
# Iteration 92: BIC = -455192.07, Edges = 91
# Iteration 93: BIC = -455179.39, Edges = 92
# Iteration 94: BIC = -455167.15, Edges = 93
# Iteration 95: BIC = -455155.83, Edges = 94
# Iteration 96: BIC = -455136.85, Edges = 95
# Iteration 97: BIC = -455117.77, Edges = 96
# Iteration 98: BIC = -455105.96, Edges = 97
# Iteration 99: BIC = -455086.47, Edges = 98
# Iteration 100: BIC = -455073.96, Edges = 99

# %%
# Final learned structure
learned_edges = [(columns[i], columns[j]) for i, j in dag.edges()]
print("\nTop 100 edges in the learned DAG:")
print(learned_edges[:100])
# Out:
# Top 100 edges in the learned DAG:
# [('st80_aVF', 'st80_III'), ('st80_aVF', 'st80_V6'), ('st80_aVF', 'st80_I'), ('st80_aVF', 'st80_V3'), ('st80_aVF', 'pcaTamp'), ('st80_aVF', 'fpTinfl1Mag'), ('st80_aVF', 'fpTinfl1Axis'), ('st80_aVL', 'st80_III'), ('st80_aVL', 'st80_I'), ('st80_aVL', 'st80_aVF'), ('st80_aVL', 'st80_V6'), ('tamp_III', 'tamp_aVF'), ('tamp_III', 'tamp_aVL'), ('tamp_III', 'tamp_I'), ('tamp_III', 'fpTinfl1Axis'), ('tamp_III', 'st80_III'), ('tamp_III', 'st80_aVL'), ('tamp_aVF', 'st80_aVF'), ('tamp_aVF', 'Tamp'), ('tamp_aVF', 'tamp_aVL'), ('tamp_aVF', 'tamp_I'), ('tamp_aVF', 'st80_V6'), ('tamp_aVF', 'fpTinfl1Axis'), ('tamp_aVF', 'st80_III'), ('tamp_aVF', 'mfpQRSaxis'), ('st80_V6', 'TrelAmp'), ('st80_V6', 'st80_V1'), ('st80_III', 'st80_V1'), ('st80_III', 'mfpQRSaxis'), ('st80_V2', 'st80_V1'), ('st80_V2', 'st80_V3'), ('st80_V2', 'tamp_V6'), ('st80_V2', 'st80_aVL'), ('st80_V2', 'pcaTamp'), ('st80_V2', 'tamp_aVL'), ('st80_V2', 'tamp_V5'), ('tamp_aVL', 'tamp_I'), ('tamp_aVL', 'st80_aVL'), ('tamp_aVL', 'st80_aVF'), ('tamp_aVL', 'fpTinfl1Mag'), ('tamp_V2', 'st80_V2'), ('tamp_V2', 'st80_aVL'), ('tamp_V2', 'tamp_III'), ('tamp_V2', 'fpTinfl1Mag'), ('tamp_V2', 'QRSd'), ('tamp_V2', 'pcaTamp'), ('st80_I', 'st80_V1'), ('st80_I', 'st80_V6'), ('tamp_I', 'fpTinfl1Mag'), ('tamp_I', 'st80_I'), ('tamp_I', 'QRSTangle'), ('tamp_I', 'Tamp'), ('tamp_I', 'st80_V6'), ('tamp_I', 'st80_aVF'), ('tamp_I', 'st80_aVL'), ('TpTe', 'HR'), ('st80_V3', 'pcaTamp'), ('st80_V3', 'fpTinfl1Mag'), ('st80_V3', 'TrelAmp'), ('st80_V3', 'QRSTangle'), ('st80_V3', 'st80_V1'), ('st80_V3', 'QRSd'), ('tamp_V6', 'tamp_aVF'), ('tamp_V6', 'st80_V6'), ('tamp_V6', 'tamp_III'), ('tamp_V6', 'QRSTangle'), ('tamp_V6', 'tamp_aVL'), ('tamp_V6', 'st80_V3'), ('tamp_V6', 'tamp_I'), ('fpTinfl1Axis', 'Tamp'), ('fpTinfl1Axis', 'QRSTangle'), ('fpTinfl1Axis', 'HR'), ('QRSd', 'TpTe'), ('QRSd', 'HR'), ('tamp_V5', 'tamp_V6'), ('tamp_V5', 'pcaTamp'), ('tamp_V5', 'tamp_aVF'), ('tamp_V5', 'tamp_I'), ('tamp_V5', 'tamp_III'), ('tamp_V5', 'st80_V3'), ('tamp_V5', 'fpTinfl1Mag'), ('fpTinfl1Mag', 'st80_III'), ('pcaTamp', 'Tamp'), ('pcaTamp', 'st80_III'), ('pcaTamp', 'fpTinfl1Axis'), ('pcaTamp', 'st80_V1'), ('mfpQRSaxis', 'QRSTangle'), ('mfpQRSaxis', 'TrelAmp'), ('mfpQRSaxis', 'QRSd'), ('Tamp', 'fpTinfl1Mag'), ('Tamp', 'TrelAmp'), ('Tamp', 'QRSTangle'), ('Tamp', 'st80_III'), ('Tamp', 'st80_V6'), ('Tamp', 'TpTe'), ('TrelAmp', 'QRSd'), ('QRSTangle', 'QRSd'), ('QRSTangle', 'TpTe'), ('QRSTangle', 'HR')]

# %%
import matplotlib.pyplot as plt

# Plotting the learned DAG
plt.figure(figsize=(16, 12))
pos = nx.spring_layout(dag, seed=42)
nx.draw(
    dag, pos, with_labels=True,
    labels={i: col for i, col in enumerate(columns)},
    node_size=1200, node_color='skyblue',
    font_size=10, font_weight='bold', arrowsize=20
)
plt.title("Learned DAG from Greedy BIC Search", fontsize=16)
plt.show()
